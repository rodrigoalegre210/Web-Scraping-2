# %%
# Importamos las librerías.
from bs4 import BeautifulSoup
import re
import requests

# %% [markdown]
# En esta parte del código, iteramos sobre una lista de URLs que corresponden a diferentes secciones dentro de la categoría "**Tecnología**" de MercadoLibre.

# %%
URLs_BASE = ['https://www.mercadolibre.com.ar/c/celulares-y-telefonos#menu=categories', 
             'https://www.mercadolibre.com.ar/c/computacion#menu=categories',
             'https://www.mercadolibre.com.ar/c/camaras-y-accesorios#menu=categories',
             'https://www.mercadolibre.com.ar/c/electronica-audio-y-video#menu=categories']

productos = []

for url in URLs_BASE:
    pedido_obtenido = requests.get(url)
    
    if pedido_obtenido.status_code == 200: # Nos aseguramos que la página se descargó bien.
        soup = BeautifulSoup(pedido_obtenido.text, "html.parser")

        # Buscamos contenedores de productos.
        enlaces_productos = soup.find_all('a', class_ = 'splinter-link')

        for enlace in enlaces_productos:
            url_producto = enlace.get('href')
            
            # Filtramos solo las URLs que contienen "/p/"
            if url_producto and "/p/" in url_producto:
                producto_pagina = requests.get(url_producto)

                if producto_pagina.status_code == 200: # Nos aseguramos que la página se descargó bien.
                    producto_soup = BeautifulSoup(producto_pagina.text, "html.parser")

                    # Extraemos la información del producto.
                    nombre_producto = producto_soup.find_all('h1', class_ = 'ui-pdp-title')
                    precio_producto = producto_soup.find_all('span', class_ = 'andes-money-amount__fraction')
                    rating_producto = producto_soup.find_all('span', class_ = 'ui-pdp-review__rating')
                    reseña_producto = producto_soup.find_all('p', class_ = 'ui-review-capability-comments__comment__content ui-review-capability-comments__comment__content')

                    # Guardamos los datos.
                    productos.append({
                        "Nombre": nombre_producto,
                        "Precio": precio_producto,
                        "Rating": rating_producto,
                        "Reseña": reseña_producto
                    })

    else:
        print(f'Error al acceder a {url}')

# %%
productos
# Out:
# [{'Nombre': 'Samsung Galaxy A06 64gb 4gb Black',
#   'Precio': '239.999',
#   'Rating': '4.7',
#   'Reseña': 'Arranca frena y dobla.'},
#  {'Nombre': 'Samsung Galaxy A15 128 GB Azul claro 4 GB RAM',
#   'Precio': '419.999',
#   'Rating': '4.7',
#   'Reseña': 'No le doy 5 estrellas porque me parece que por lo que cuesta el equipo, al menos podrían poner un cargador.'},
#  {'Nombre': 'Samsung Galaxy A06 128gb 4gb Black',
#   'Precio': '299.999',
#   'Rating': '4.7',
#   'Reseña': 'Arranca frena y dobla.'},
#  {'Nombre': 'Samsung Galaxy A06 64gb 4gb Light Blue',
#   'Precio': '239.999',
#   'Rating': '4.7',
#   'Reseña': 'Arranca frena y dobla.'},
#  {'Nombre': 'Tecno Spark 20c Dual SIM 128 GB Negro 4 GB RAM',
#   'Precio': '269.999',
#   'Rating': '4.7',
#   'Reseña': 'Super recomendable 👌 un teléfono que supera a las otras marcas. Sin duda muy delicado , es grande , calidad de cámara excelente 👌 memoria para rato y tiene muchas cosas más para seguir descubriendo me encanta por que trae accesorios como auriculares, funda para el celular y protector de pantalla , y su cargador. Sin duda es un telefonazo muchos piensan que es un iphone.\nNo duden en comprar sinceramente para juegos como fre fire y entre otras que son pesado ni se tilda.'},
#  {'Nombre': 'Samsung Galaxy A15 128 GB amarillo 4 GB RAM',
#   'Precio': '419.999',
#   'Rating': '4.7',
#   'Reseña': 'No le doy 5 estrellas porque me parece que por lo que cuesta el equipo, al menos podrían poner un cargador.'},
#  {'Nombre': 'Samsung Galaxy A15 128 GB Negro azulado 4 GB RAM',
#   'Precio': '419.999',
#   'Rating': '4.7',
#   'Reseña': 'No le doy 5 estrellas porque me parece que por lo que cuesta el equipo, al menos podrían poner un cargador.'},
#  {'Nombre': 'Samsung Galaxy A06 128gb 4gb Light Blue',
#   'Precio': '299.999',
#   'Rating': '4.7',
#   'Reseña': 'Arranca frena y dobla.'},
#  {'Nombre': 'Tecno Spark 20c Dual SIM 256 GB negro 4 GB RAM',
#   'Precio': '299.999',
#   'Rating': '4.7',
#   'Reseña': 'Super recomendable 👌 un teléfono que supera a las otras marcas. Sin duda muy delicado , es grande , calidad de cámara excelente 👌 memoria para rato y tiene muchas cosas más para seguir descubriendo me encanta por que trae accesorios como auriculares, funda para el celular y protector de pantalla , y su cargador. Sin duda es un telefonazo muchos piensan que es un iphone.\nNo duden en comprar sinceramente para juegos como fre fire y entre otras que son pesado ni se tilda.'},
#  {'Nombre': 'Motorola Moto G04s Satin Blue 64gb 4gb',
#   'Precio': '279.999',
#   'Rating': '4.7',
#   'Reseña': 'Excelente. Baterías re aguanta.\nCámara hermoso imagen 10 puntos.\nLástima que hera para mi marido🙂.'},
#  {'Nombre': 'Samsung Galaxy A55 128gb 8gb Awesome Lemon',
#   'Precio': '939.999',
#   'Rating': '4.8',
#   'Reseña': 'Es hermoso 😍 se siente muy premium, lastima que por el precio no venga cargador aunque sea pero bueno.'},
#  {'Nombre': 'Zte Smartphone Blade A54 128gb 4gb Ram Gris',
#   'Precio': '378.699',
#   'Rating': '4.5',
#   'Reseña': 'Compré 2 para mis hijos. No me imaginé que serían tan buenos. Calidad percibida visual muy fachero. Calidad percibida al tacto un poco más de calidad le falta. Las cámaras sacan muy buenas fotos. Mis hijos los usan para jugar obviamente. Los juegos corren muy muy bien sin lagueos. Volvería a comprar sin duda. Los estoy pensando para mí.'},
#  {'Nombre': 'Smartphone Tcl 50 5g T613p 6.56 Hd+ 256gb Space Gray 6gb Ram',
#   'Precio': '349.999',
#   'Rating': '4.9',
#   'Reseña': 'Cambié de una celu de gran marca a tcl ,la verdad no me arrepiento. Ahora cambio mí tcl 30+ por este que tiene más capacidad pero no tiene nada que envidiar a las grandes marcas. Ah y en la caja viene con auriculares cargador y funda. Una genialidad!!!.'},
#  {'Nombre': 'Samsung Galaxy A05 64 GB Negro 4 GB RAM',
#   'Precio': '289.999',
#   'Rating': '4.7',
#   'Reseña': 'Muy lindo no saca muy buenas fotos lo único pero muy lindo y rápido funciona.'},
#  {'Nombre': 'Motorola Moto G04s Sunrise Orange 64gb 4gb',
#   'Precio': '399.999',
#   'Rating': '4.7',
#   'Reseña': 'Excelente. Baterías re aguanta.\nCámara hermoso imagen 10 puntos.\nLástima que hera para mi marido🙂.'},
#  {'Nombre': 'Samsung Galaxy A54 5G 256 GB  Awesome graphite 8 GB RAM',
#   'Precio': '939.999',
#   'Rating': '4.7',
#   'Reseña': 'El valor es alto, pero si lo que buscas es una buena cámara sin llegar a un gama alta es muy recomendable, cualquier samsung arriba del a33 5g lo es, vengo de ese y me pase a este. El ecosistema de samsung es de los mejores. La batería le dura con el uso que le doy aprox un día y medio, la pantalla se ve espectacular y el sonido es muy bueno, sin llegar a ser de los mejores. Su procesador no es elas rápido de la gama, pero para el uso que le doy va más que sobrado, sus 8gb de memoria ram ayudan a que la experiencia sea buena, muy a destacar. La memoria interna 256gb de mi versión parece que no se va a acabar con facilidad, más tomando en cuenta que se puede agregar una memoria micro sd, en mi caso uso una sandisk extreme pro de 128gb. Contento con la compra. Adjunto fotos tomadas con la cámara, de noche, en malas condiciones de luz.'},
#  {'Nombre': 'Samsung Galaxy A05 64 GB verde claro 4 GB RAM',
#   'Precio': '319.999',
#   'Rating': '4.7',
#   'Reseña': 'Muy lindo no saca muy buenas fotos lo único pero muy lindo y rápido funciona.'},
#  {'Nombre': 'Funda universal para teléfono móvil, brazalete para correr, color: negro liso',
#   'Precio': '3.469',
#   'Rating': '4.0',
#   'Reseña': 'Sin reseña'},
#  {'Nombre': 'Cargador Fast Apple Original  iPhone 13 13 Pro Max Usb-c 20w Color Blanco - Distribuidor Autorizado',
#   'Precio': '94.499',
#   'Rating': '4.9',
#   'Reseña': 'Excelente! original, se nota la diferencia con uno trucho. Carga rapidisimo y cuidas la bateria de tu iphone. Es caro, pero no seas rata! gastaste 800/1000 dolares en un iphone, gasta plata tmb en cuidar su bateria.'},
#  {'Nombre': 'Cargador Samsung 25w Ultra Rápido Carga Rapida S24',
#   'Precio': '45.000',
#   'Rating': '4.7',
#   'Reseña': 'Muy bueno! la carga es super rápida para ser tan solo 25w. En mi caso lo uso en mi galaxy a34 y va excelente.'},
#  {'Nombre': 'Cargador Fast Apple Original  iPhone 13 13 Pro Max Usb-c 20w Color Blanco',
#   'Precio': '59.615',
#   'Rating': '4.9',
#   'Reseña': 'Comprar solo cargadores originales para productos de apple. Un cargador original no puede costar $4000 (enero 2023) siendo que en un apple store cuesta u$d 20 dólares. Las copias son idénticas y la caja también lo es, pero por dentro nada que ver. Cuiden sus dispositivos, que son bastante caros.'},
#  {'Nombre': 'Cargador compatible con Samsung - 45w USB-C Color Negro',
#   'Precio': '22.300',
#   'Rating': '4.8',
#   'Reseña': 'Excelente cargador es el original de samsung 45w modelo ep-t4510xbsgar. Los materiales son originales, es mucho más grande que los cargadores comunes de 25w, el cable es original samsung que soporta 5a y es más largo y grueso que los comunes. Cuando lo conecto me informa que la carga rápida es 2. 0 lo cual verifica la autenticidad del mismo. Excelente producto, no calienta mucho y funciona perfecto. Recomendado!.'},
#  {'Nombre': 'Cargador Motorola 68w Tipo C Usb Tipo C De Pared Con Cable Carga Rápida Negro',
#   'Precio': '34.499',
#   'Rating': '4.7',
#   'Reseña': 'Esta tremendo, si es réplica la verdad que ni se nota, es igual que el original y me cargo al toque el celular, en 15 min ya tengo bateria para todo el día.'},
#  {'Nombre': 'Cargador Adaptador Samsung 25w Sin Cable Carga Rapida Blanco',
#   'Precio': '22.518',
#   'Rating': '4.8',
#   'Reseña': 'Carga perfectamente el samsung a14.'},
#  {'Nombre': 'Cargador Para Auto 2 Entradas Usb Carga Rapida 3.0 Luz Led Color Blanco',
#   'Precio': '7.028',
#   'Rating': '4.4',
#   'Reseña': 'Carga rápido.'},
#  {'Nombre': 'Cargador Ditron Carga Rapida 4.2a Celular Cable Micro Usb 2a',
#   'Precio': '10.412',
#   'Rating': '4.5',
#   'Reseña': 'Excelente para zte carga rápida.'},
#  {'Nombre': 'Cargador Turbo Power Motorola Usb C 33w Pared Color Negro',
#   'Precio': '39.999',
#   'Rating': '4.7',
#   'Reseña': 'Desconozco si es el cargador o el teléfono, no se me activa el power.'},
#  {'Nombre': 'Cargador Xiaomi 33w Charger (type-a) Color Blanco',
#   'Precio': '70.105',
#   'Rating': '4.7',
#   'Reseña': 'El producto es excelente pude recuperar la carga turbo como el que venía de fabrica.'},
#  {'Nombre': 'Cargador Móvil Gadnic Con Lde Indicador De Batería 25000 Mah Color Negro',
#   'Precio': '42.999',
#   'Rating': '4.6',
#   'Reseña': 'Una maza, nos cargo los dos celus al 100% y quedó para cargar más todavía. Tema peso y comodidad son muy exagerados no pesa tanto, es re cómodo para llevar atrás del celu, no pesa en el bolsillo, no pesa en la riñonera, es re cómodo la verdad la mejor compra que hice 💕.'},
#  {'Nombre': 'Motorola Turbo Power 20w USB SA18D59386 Negro',
#   'Precio': '13.530',
#   'Rating': '4.8',
#   'Reseña': 'Producto tal cual foto, y de muy buenas calidad, funciona a la perfecto, lo volvería a comprar.'},
#  {'Nombre': 'Baseus CATKLFBG1 Cable Usb A Usb-c 1 Metro 3a Carga Rápida Color Negro/Gris',
#   'Precio': '9.500',
#   'Rating': '4.7',
#   'Reseña': 'Para todos los que preguntan, si, es compatible con iphone 15, y apple carplay. Yo lo uso en iphone 15pro.'},
#  {'Nombre': 'Cable Baseus Usb A / Lightning 2.4a de 1 metro Color Negro y Gris',
#   'Precio': '8.889',
#   'Rating': '4.8',
#   'Reseña': 'Excelente producto, se ve resistente y de buena calidad y carga muy bien el celular. Lo recomiendo 100%!.'},
#  {'Nombre': 'Cable Baseus Usb-a / Usb-C  Color Rojo y negro  de 3 metros',
#   'Precio': '13.889',
#   'Rating': '4.9',
#   'Reseña': 'Excelente cable, lo compre para conectar un joystick de xbox directamente a la consola para no consumir pilas y funciona de maravilla. 100% para los gamers y los 3 metros de largo es ideal para una buena distancia con el tv.'},
#  {'Nombre': 'Cable Usb Tipo C 1 Metro 2.4a Carga Rápida Color Blanco',
#   'Precio': '3.287',
#   'Rating': '4.4',
#   'Reseña': 'Muy bueno, espectacular.'},
#  {'Nombre': 'Cable Cargador Smartphone Usb A Micro Usb Carga Rapida 1,2mt Color Blanco',
#   'Precio': '5.725',
#   'Rating': '4.4',
#   'Reseña': 'Todo ok. Carga rápido. Es lo que ofrecen.'},
#  {'Nombre': 'Cable De Carga Rapida 100w Usb-c A Usb-c 2m Baseus Cristal Color Negro',
#   'Precio': '19.000',
#   'Rating': '4.9',
#   'Reseña': 'No me canso de decirlo: baseus calidad.'},
#  {'Nombre': 'Cable De Datos Jd D-30ac Usb A Usb Tipo C 2.4a Carga Rapida Color Negro',
#   'Precio': '4.999',
#   'Rating': '4.6',
#   'Reseña': 'Excelente, carga y mueve datos a buena velocidad. El mallado es resistente. Muy buen precio.'},
#  {'Nombre': 'Cable Usb A Tipo-c 3a 1m Gris Negro Baseus',
#   'Precio': '9.889',
#   'Rating': '4.6',
#   'Reseña': 'La mejor alternativa para no regalarle plata a apple.'},
#  {'Nombre': 'Ugreen Cable Carga Rapida 4.0 Usb C - 1m Blindado - Mac',
#   'Precio': '11.310',
#   'Rating': '4.8',
#   'Reseña': 'Buen producto! me funciona perfecto.'},
#  {'Nombre': 'Ugreen Us284 Cable Cargador Usb C Angulo 90° 18 W 480 Mbps 1 M',
#   'Precio': '12.079',
#   'Rating': '4.9',
#   'Reseña': 'Muy cómodo y de excelente calidad. Uso para carga y transferencia de datos sin problema.'},
#  {'Nombre': 'Cable Samsung Tipo C- Original- Flex',
#   'Precio': '4.573',
#   'Rating': '3.7',
#   'Reseña': 'No lo vale, no sirve. Pésima calidad. Hace que la batería se cargue super lento, demora 3 veces más q lo normal.\nY resalto que tengo la base del cargador q es original.\nNo sirve, no gasten al vicio.'},
#  {'Nombre': 'Cable usb tipo C Baseus negro/gris con entrada USB salida USB-C',
#   'Precio': '13.889',
#   'Rating': '4.9',
#   'Reseña': 'Excelente cable, lo compre para conectar un joystick de xbox directamente a la consola para no consumir pilas y funciona de maravilla. 100% para los gamers y los 3 metros de largo es ideal para una buena distancia con el tv.'},
#  {'Nombre': 'Cable Usb A Micro Usb Telado Colores Ultra Rapido Ditron 1mt Color Rojo',
#   'Precio': '6.975',
#   'Rating': '4.7',
#   'Reseña': 'Mallado, lindo, encaja como que-te-dije de brayan en una mama luchona. Diez puntos.'},
#  {'Nombre': 'Cable Samsung Usb-c A Usb-c 1.8m 5a 1000w Data Carga Rapida Color Blanco',
#   'Precio': '37.600',
#   'Rating': '4.6',
#   'Reseña': 'Super recomendado, se me estaba por romper el del celular y queria un cable original que soportara la carga rápida. Es un 10 y hasta es mas largo que los cables que suelen venir con los celus!.'},
#  {'Nombre': 'Cable Reforzado Usb C Carga Rapida 4 En 1 Megan Tech 120cm Color Negro',
#   'Precio': '13.650',
#   'Rating': '4.6',
#   'Reseña': 'Excelente producto. En instagram el mismo cable, misma marca, los delincuentes te lo cobran 4 veces más. Es de excelente calidad. La conectividad perfecta.'},
#  {'Nombre': 'Cable Cargador Para iPhone 1 Metro Compatible iPhone iPad',
#   'Precio': '3.146',
#   'Rating': '3.9',
#   'Reseña': 'Excelente todo la verdad.'},
#  {'Nombre': 'Cable Datos Y Carga 3a Tipo C A Tipo C 1 Metro Color Blanco.',
#   'Precio': '2.089',
#   'Rating': '4.4',
#   'Reseña': 'Lo que esperaba!.'},
#  {'Nombre': 'Monitor Ips Samsung 24 Full Hd 75hz 5Ms bordes finos T350FHL Freesync Color Negro',
#   'Precio': '309.999',
#   'Rating': '4.9',
#   'Reseña': 'Exelente el monitor buena pantalla calidad en colores muy muy bueno,lo recomiendo 💯% !!.'},
#  {'Nombre': 'Notebook Exo Smart T38 Intel N4020 4gb Ssd128gb Windows 11 Color Gris',
#   'Precio': '559.999',
#   'Rating': '4.6',
#   'Reseña': 'Es perfecta, quede fascinada en estética, velocidad y duración de batería 🫶🏻 súper conforme ❤️.'},
#  {'Nombre': 'E-reader Kindle 11th Gen 2024 16gb negro con pantalla de 6',
#   'Precio': '247.999',
#   'Rating': '4.9',
#   'Reseña': 'Se lo regalé a mi novio. Quedó maravillado, tanto que hasta me convenció de comprarme uno para mi. La tinta digital es una cosa de locos, tenes que cerrar el estadio.'},
#  {'Nombre': 'Notebook Aspire Go Intel i3 N305, DDR5 8Gb Ram, 128Gb SSD, Pantalla 15.6" Full HD, Windows 11 (AG15-31P-3947)',
#   'Precio': '1.047.999',
#   'Rating': '4.7',
#   'Reseña': 'Es preciosa, la pantalla bien grande como yo queria porque tengo problemas visuales. Estoy re feliz con mi compra.'},
#  {'Nombre': 'Disco Sólido SSD Kingston A400 960GB',
#   'Precio': '76.930',
#   'Rating': '4.9',
#   'Reseña': 'Lo instale en 5 minutos con la pc encendida, con el destornillador toque la fuente y me di un correntazo que del susto me golpee la cabeza contra el escritorio y me levanté a las 3 horas y el disco duro seguía perfecto.'},
#  {'Nombre': 'Notebook Lenovo Ideapad 1 15alc7 Abyss Blue Amd Ryzen 7 5700u 16gb De Ram 512 Gb Ssd, Integrated Amd Radeon Graphics 60 Hz 1920x1080px Windows 11 Home',
#   'Precio': '2.264.999',
#   'Rating': '4.8',
#   'Reseña': 'La notebook es excelente, no se puede pedir mas. El unico fallo que quizas puede tener es los angulos de vision de la pantalla, pero mas alla de eso ninguno (y es entendible por el precio). Para los que buscan trabajar en diseño es perfectamente compatible, uso photoshop, premiere, illustrator y cinema4d sin ningun problema. Para programar? entorno de desarrollo mas que fluido con ubuntu, vscode, sqlserver y todos los complementos. Para jugar: valorant y league oflegends todo en alto sin ningun problema en 80/100fps, cs2 todo bajo en 1920x1080 60fps. La bateria de la notebook es un punto muy fuerte, en la universidad puede durar tranquilamente de 7 a 9 horas de trabajo liviano en word, notion y un poco de programacion, para trabajos pesados de edicion la duracion desciende a 3/4 horas, ya para jugar valorant dura poco mas de una partida. Cuando compre la notebook me costo mucho encontrar reseñas, ojala les sirva y mas que recomendado!.'},
#  {'Nombre': 'Kit 10 Resma Pampa A4 multifunción de 500 hojas de 70 gr color blanco',
#   'Precio': '73.325',
#   'Rating': '4.8',
#   'Reseña': 'Que se puede opinar sobre hojas a4.'},
#  {'Nombre': 'Monitor Gamer Samsung con pantalla de 22" 75Hz 220V y resolución Full HD',
#   'Precio': '279.999',
#   'Rating': '4.8',
#   'Reseña': 'Muy bueno, más de lo que esperaba!!!!!!.'},
#  {'Nombre': 'Repetidor Extensor de rango Wi-Fi 5 Doble Banda TP-Link RE200 AC750',
#   'Precio': '42.950',
#   'Rating': '4.6',
#   'Reseña': 'Sin reseña'},
#  {'Nombre': "Notebook Lenovo Pentium Silver N5030 4gb 128gb 14'' Plateado",
#   'Precio': '740.499',
#   'Rating': '4.7',
#   'Reseña': 'No puedo opinar de la batería porque aún no la pude testear.\nHasta ahora operativamente todo funciona muy bien.'},
#  {'Nombre': 'Kit 10 Resmas Boreal A4 75grs X 500h Caja X10 Unidades Color Blanco',
#   'Precio': '84.999',
#   'Rating': '4.8',
#   'Reseña': 'Lo único que vinieron varios paquete roto.'},
#  {'Nombre': 'Notebook Asus Vivobook 14 Intel Core I3 1215u 16gb De Ram 512gb Ssd Full Hd Windows 11 Home',
#   'Precio': '1.058.999',
#   'Rating': '4.7',
#   'Reseña': 'Me la compre para el estudio/trabajo y hasta ahora todo bien(la tengo hace menos de 1 mes). Me parece super bien para lo que sale (la compre en 1 pago que salia más barato) es del tamaño ideal para que entre en una cartera y llevar a todos lados, no pesa tanto. Venia de una experiencia pesima con una notebook lenovo y esta fue como tocar el cielo con las manos. Por ahora todo ok👌🏻.'},
#  {'Nombre': 'Resma Papel Punax A4 Gramaje 75 Gr. 500 Hojas Caja X 10 Color Blanco acabado Mate',
#   'Precio': '68.998',
#   'Rating': '4.8',
#   'Reseña': 'Son excelente, son de papel, de color blanco, se puede escribir arriba de ellas y hasta se pueden doblar y hacer origamis. Estoy muy satisfecho. Entran perfecto en mi impresora y cuando le doy al botón de imprimir en mi computadora, pasan desde el lado de arriba por dentro hasta que salen por debajo con todo impreso gracias a la tinta de la impresora. No son buenas para aseo personal porque son muy rígidas y no son suaves y pueden raspar un poco si las uso para limpiar o para secarme, pero las recomiendo. No las mojen porque se aflojan y se ponen babosas, perdiendo su forma y rompiéndose.'},
#  {'Nombre': 'Fuente de alimentación Corsair CX750 750W 80+ Bronze',
#   'Precio': '100.700',
#   'Rating': '4.8',
#   'Reseña': 'Mas silencioso que el patilana de la vecina, excelente calidad de materiales.'},
#  {'Nombre': 'Impresora multifunción a color Epson EcoTank L3210 220V',
#   'Precio': '500.000',
#   'Rating': '4.7',
#   'Reseña': 'Le doy 5 estrellas. Precio y calidad. Es la 3er impresora que compro en un año. Uso doméstico 10 de 10.\nPor cuestiones económicas la uso para imprimir y fotocopiar y la máquina se porta excelente. Cada aproximadamente 6mil impresiones hay que hacerle un resep de almohadillas.\nY la maquina tiene una vida útil de 65mil impresiones aproximadamente. Luego ya pide un mantenimiento que conviene comprar una nueva. Por eso voy por la tercera. Y no compro una industrial por que estan carísimas. Todo lo que cuento es verdad. Las 2 anteriores eran las l3110. Ahora estoy con la l3210. Ojala le sirva mi experiencia.\nSaludos.'},
#  {'Nombre': 'Disco Sólido SSD Kingston A400 960GB',
#   'Precio': '76.930',
#   'Rating': '4.9',
#   'Reseña': 'Lo instale en 5 minutos con la pc encendida, con el destornillador toque la fuente y me di un correntazo que del susto me golpee la cabeza contra el escritorio y me levanté a las 3 horas y el disco duro seguía perfecto.'},
#  {'Nombre': 'Placa de video AMD Sentey Radeon RX 550 4GB GDRR5 6000mhz',
#   'Precio': '105.799',
#   'Rating': '4.7',
#   'Reseña': 'Un lujo para procesadores de 4 núcleos con 16 de ram te permite jugar una banda de titulos.'},
#  {'Nombre': 'Procesador AMD Ryzen 7 5700G 100-100000263BOX de 8 núcleos y 4.6GHz de frecuencia con gráfica integrada',
#   'Precio': '255.617',
#   'Rating': '4.9',
#   'Reseña': 'Sin reseña'},
#  {'Nombre': 'Gabinete Gamer Sentey H10 Lateral Frente Transparente White Color Blanco Sin Fans',
#   'Precio': '67.999',
#   'Rating': '4.8',
#   'Reseña': 'Es un lindo gabinete. Estéticamente super clean, pequeño y con el espacio justo para la gestion de cables. Obligatorio tener un buen sistema de enfriamiento y los 5 coolers, es medio hornito.'},
#  {'Nombre': 'Placa de video Nvidia MSI Ventus GeForce RTX 30 Series RTX 3060 VENTUS 2X 12G OC OC Edition 12GB Gddr6',
#   'Precio': '666.369',
#   'Rating': '4.9',
#   'Reseña': 'Excelente compra. Me sirve para mandar captura a mis amigos de que los juegos me corren a 180 fps, ahora solo se burlan de mi por que resultaba que el problema eran mis manos. La manquedad no se cambia con compras en ml.'},
#  {'Nombre': 'Microprocesador Pc AMD Ryzen 5 5500 100-100000457BOX 16mb 3.6ghz Zen 3 Socket Am4 de 6 Nucleos 5ta Generación DDR4',
#   'Precio': '125.999',
#   'Rating': '4.8',
#   'Reseña': 'Anda muy bien, tiene un gran rendimiento. Punto flojo es que es pci-e gen3 en vez de 4.'},
#  {'Nombre': 'Capturadora De Video Hdmi Full Hd Gran Calidad 1080p 30hz',
#   'Precio': '8.620',
#   'Rating': '4.7',
#   'Reseña': 'Muy bueno , exelente relación precio calidad , ahora puedo jugar maicraf de pley 3 en mi notebook , adjunto foto de mi setup y adjunto foto mía🥵.'},
#  {'Nombre': 'Gabinete Gamer Level Up Cassiopeia Atx Led Rgb Ventilador Color Negro',
#   'Precio': '99.999',
#   'Rating': '4.7',
#   'Reseña': 'La verdad, lo compre con miedo…. Me sorprendió para bien, muy sólido de buena calidad, quizá no tenga el mejor flujo de aire pero para compus standard va más que bien, calidad precio 👍.'},
#  {'Nombre': 'Disco sólido interno Western Digital WD Green WDS100T3G0A 3 1TB verde',
#   'Precio': '107.999',
#   'Rating': '4.8',
#   'Reseña': "Razones para comprarte un ssd:.\n-le rompe el orto en todo a un hdd.\nFin.\nOkno.\nObviando el hecho de que el ssd es en promedio 10 veces más ràpido, 1tb de espacio es lo que te compras o bien para full sistema (en caso de no tener más presupuesto) o bien estas buscando un disco para otras cosas (archivos de trabajo juegos y demas) la ''best build'' serìa tener un m. 2 con el sistema operativo y uno de estos para el resto de cosas.\nYo ya tenia uno de 500gb para el sistema y archivos que uso dia a dìa sumado a programas, y un disco duro con cosas del trabajo, compre este para juegos y no me arrepiento.\n¿te merece la pena un blue? yyyy a mi parecer no, la gama blue es ''más ràpida'' pero si chequeas test el margen no amerita (a mi parecer) el gasto.\nFuera de eso todo bien, de resto lo de siempre no hay un motivo para no querer tener un ssd en tu quipo salvo que quieras màs ''coste/espacio'' (osea pagar màs teniendo màs espacio a coste de la velocidad, cosa que te dan los hdd)."},
#  {'Nombre': 'Motherboard Gigabyte Amd A520m K V2 Ddr4 Gamer Color Negro',
#   'Precio': '89.999',
#   'Rating': '4.8',
#   'Reseña': 'Perfecto: me tomó el ryzen 5 5600g sin ninguna actualizacion.'},
#  {'Nombre': 'Placa de video Nvidia MSI  Ventus 2X GeForce RTX 40 Series RTX 4060 GeForce RTX 4060 VENTUS 2X BLACK 8G OC Black OC Edition 8GB',
#   'Precio': '737.869',
#   'Rating': '4.9',
#   'Reseña': 'Lo ideal para despreocuparte de correr todo a calidades ultra en 1080p a bajo consumo y temperatura. Incluye todas las ultimas tecnologías ¡no lo dudes!.'},
#  {'Nombre': 'Procesador gamer AMD Ryzen 5 5600X 100-100000065BOX de 6 núcleos y 4.6GHz de frecuencia',
#   'Precio': '326.619',
#   'Rating': '4.9',
#   'Reseña': 'Una bestia de procesador.\nTiene tanta potencia que supera al i9 10900k de 10 nucleos 20 hilos en gaming y le pisa los talones en produccion (excepto en aplicaciones que usen mas de 12 hilos, ahí le pasa el trapo), consumiendo solo 65 - 70watts (hwmonitor) y le pisa los talones al 11900k.\nLo unico que puede parecer raro y que seguramente lean en internet es que calienta como el infierno y es cierto, le pones un juego y se dispara a 75-80 grados, y compilando proyectos ha llegado a 90 y pico de grados. El tema es que esto es a proposito y que esta diseñado así segun la propia amd. El procesador empieza a hacer throtling a los 95 grados, por lo que si nunca llega a 95, nunca hace throtling.\nEl cooler de stock sirve, el tope fue 96 grados por un momento compilando y firmando un proyecto de android bastante pesadito, y fue solo un momento.\nEn gaming, 85 grados tope en red dead redemption 2, en el resto no supera los 80, incluso en jugos como battlefield 1. De nuevo, esto es diseño de amd y es como debería andar según ellos.\nLlega sin problemas a los 4. 65ghz en trabajos cortos y normalmente rondando 4. 5-4. 55ghz en gaming en todos los nucleos.\nJuegos como valorant, csgo, battlefield 1, ni se inmuta, y si limitás los fps ni se calienta. 144 fps solidos con el limitador, ningun bajón, stutter, nada.\nSi le conseguís un cooler mejor vas a notar que igual va a subir a 85 grados porque igual esta diseñado así, ni con un aio de 240mm.\nEn fin, excelente procesador.'},
#  {'Nombre': 'Fuente de alimentación Corsair CX750 750W 80+ Bronze',
#   'Precio': '100.700',
#   'Rating': '4.8',
#   'Reseña': 'Mas silencioso que el patilana de la vecina, excelente calidad de materiales.'},
#  {'Nombre': 'Adaptador Usb 3.0 A Sata 2.5 Discos Rigidos Y Grabadoras Color Negro',
#   'Precio': '6.120',
#   'Rating': '4.7',
#   'Reseña': 'Funciona muy bien. Tengo un ssd conectado a una raspberry pi 4.'},
#  {'Nombre': 'Gabinete Gamer Rgb Haxly E910 Usb 3.0 Vidrio Templado Atx Color Negro',
#   'Precio': '72.649',
#   'Rating': '4.7',
#   'Reseña': 'Bueno por el precio no pidan el metal y el peso de los gabinetes at para 486 hechos en usa en la decada del 90, algo que pesaba y mucho. Este gabinete es apto chinesco, gama inicial, para una placa atx de las de antes, esta muy bien solucionado el espacio interior y en mi caso me entro mi rx6600 amd con una placa gigabyte ga-970 sin problemas. Si quieren mas calidad y mas peso metalico vayan por algo de 100. 000 pesos para arriba.'},
#  {'Nombre': 'Placa De Video Nvidia Rtx 2060 Super 8gb Gddr6 - Colorful',
#   'Precio': '397.376',
#   'Rating': '4.9',
#   'Reseña': 'Una marca muy barata y de muy buena calidad. En mi caso la grafica necesitó mas energia de la que dice en las espwcificaciones, obligandome a comprar una fuente mas grande. El rendimiento es espectacular, funciona mejor de lo que esperaba para una grafica de esta marca y medida. Vengo de usar una 1050ti y el cambio es muy muy notable. Muy contento.'},
#  {'Nombre': 'Procesador gamer Intel Core i5-12400F BX8071512400F de 6 núcleos y 4.4GHz de frecuencia',
#   'Precio': '184.769',
#   'Rating': '4.9',
#   'Reseña': 'Desde que adquirí este procesador no puedo para de tener relaciones sexuales, las mujeres me buscan por todos lados y me la paso diciendo que no por que ya estoy muy cansado.'},
#  {'Nombre': 'Memoria Ram Fury Beast Ddr4 Gamer Color Negro 16gb 1 Kingston Kf432c16bb/16',
#   'Precio': '69.580',
#   'Rating': '4.9',
#   'Reseña': 'Ram de la mas recomendada, tal vez cara, pero todo es caro hoy en dia en este pais. (no importa cuando leas esto).'},
#  {'Nombre': 'Disco Sólido SSD Kingston A400 480GB',
#   'Precio': '45.999',
#   'Rating': '4.9',
#   'Reseña': 'Más rápido que usain bolt en los 100 mts para iniciar windows. Basta de comprar hdd de 1-2 tb que salen lo mismo que un ssd de 480. Basta, que tenés que meter en la pc para elegir espacio y no la velocidad de la luz que tienen estos discos??. Hoy en día todo está en la nube o stream, basta de descargar triple x para llenar ese hdd lechoso para cuando se te corta internet. Basta, te compras uno de estos, si no te alcanza el espacio esperas dos, tres meses y te gatillas otro, cada vez bajan más de precio. Y el hdd lo podés usar de buen pisapapeles.'},
#  {'Nombre': 'Placa Madre Asus Tuf Gaming B450m Plus 2  Ryzen M.2 Usb 3.2',
#   'Precio': '145.679',
#   'Rating': '4.8',
#   'Reseña': 'Excelente placa, un detalle es el tema de la bios, si se activa el oc y se desbloquea la memoria ram no funciona el oc automatico y queda fijo el micro a 3. 9 ghz al menos con rayzen serie 5000, tal vez se solucione actualizando el bios, el que trae es de 2022 y hay una actualizacion de enero de 2024. El test stress se hizo en cinebench 23 con rayzen 7 5700x un disipador se-224-xts black, 16 de ram (un solo modulo single channel) en un gabinete raidmax x616 con una fuente de 800w plus bronce y un gpu de 6gb de vram, un disco de arranque patriot de 480 gb y un secundario ironwolf.'},
#  {'Nombre': 'Cable Conversor Hdmi A Vga Conversor Netbook 1080p Fhd',
#   'Precio': '3.296',
#   'Rating': '4.5',
#   'Reseña': 'Comento por que al final la computadora tenía para hdmi 🙃 qué pelot… ja.'},
#  {'Nombre': 'Hub Usb 3.0 Multiplicador 7 Teclas Led 5 Gbps + Fuente 5v',
#   'Precio': '22.999',
#   'Rating': '4.4',
#   'Reseña': 'Satisfecho de conseguir un hub con fuente. Anda bien.\nNota: las fichas usb permiten movimiento lateral y se desconecta el dispositivo enchufado si se lo mueve. Es un problema que tuve en muchos otros elementos con conexión usb.'},
#  {'Nombre': 'Cable Splitter Arctic Para Fan Cooler 4 Pines Pwm 1x4 Enchufes',
#   'Precio': '5.500',
#   'Rating': '4.9',
#   'Reseña': 'Cumple qsy, es un cable y tiene una única función.'},
#  {'Nombre': 'Hub Aluminio Usb C 4 Puertos Usb 3.0 Compatible Mac Win Lin',
#   'Precio': '5.818',
#   'Rating': '4.5',
#   'Reseña': 'Lo compre sin saber si me iba a funcionar con el celu y anda super, lo recomiendo!!!.'},
#  {'Nombre': 'Cable de red Vention Cat8 Certificado -  2 metros - Premium Patch cord - Blindado Sstp Rj45 Ethernet 40gbps - 2000 Mhz - 100% cobre - IKABH',
#   'Precio': '7.279',
#   'Rating': '4.8',
#   'Reseña': 'Tengo 500mb por fibra y con el cable qué tenia antes me tiraba 50mb. Cambie por este y me tira los 500mb. Lo recomiendo se observa de calidad.'},
#  {'Nombre': 'Conversor Adaptador Hdmi A Vga Activo Con Audio Local Color Blanco',
#   'Precio': '7.999',
#   'Rating': '4.6',
#   'Reseña': 'Muy bueno, lo utilizo para la play 4, lo compré hace 15 días y no tuve ninguna clase de problemas.\nLo recomiendo. 10/10 ☝️🤓.'},
#  {'Nombre': 'Cable De Red Skyway 20 Metros Patch Cord Rj45 Utp Lan Ethernet Cat 5e Color Gris',
#   'Precio': '8.250',
#   'Rating': '4.8',
#   'Reseña': 'Lo compré para que me dejen de romper las bolas en el laburo, y ahora me anda internet a las re chapas. El mejor cable del mundo lo amo. Te quiero mucho cable ethernet.'},
#  {'Nombre': 'Adaptador Usb-c Hub 5 En 1, 1 Hdmi 4k, 3 Usb, 1 Type-c 100w Hub Ugreen',
#   'Precio': '54.099',
#   'Rating': '4.8',
#   'Reseña': 'Funciona muy bien, buena construcción del hub. Para tener en cuenta la ficha hembra usb c que trae es únicamente para cargar el dispositivo no sirve como puerto de comunicación.'},
#  {'Nombre': 'Cable Vga Monitor 3 Metros Macho Pc Con Filtro Cobre 100',
#   'Precio': '5.999',
#   'Rating': '4.6',
#   'Reseña': 'Excelente.'},
#  {'Nombre': 'Cable Red 10 Metros Para Router Modem Pc Notebook Ps4 Fact A',
#   'Precio': '3.470',
#   'Rating': '4.5',
#   'Reseña': 'Anda perfecto 👌 muchísimas gracias.'},
#  {'Nombre': 'Hub Usb Multiplicador 7 Puertos Usb Con Teclas Y Leds Azules',
#   'Precio': '9.999',
#   'Rating': '4.4',
#   'Reseña': 'No tengo mucho por decir, cumple con su funcion.'},
#  {'Nombre': 'Cable Vention Hdmi 2.1 - Certificado Profesional - 8k Hdr Earc HDCP 144hz - Blindado 48 gbps Oro - Premium Gamer Full HD - 3 Metros - AANBI',
#   'Precio': '14.200',
#   'Rating': '4.8',
#   'Reseña': 'Excelente todo da los 120 hz es con patentado.'},
#  {'Nombre': 'Adaptador Auriculares Micrófono Gamer Plug 3.5 Computadora',
#   'Precio': '3.149',
#   'Rating': '4.3',
#   'Reseña': 'Muy bueno, lo recomiendo, es mas econocimo que otros adaptadores, eso si, no se fien de los bajos precios por las dudas, pero este adaptador funciona de 10.'},
#  {'Nombre': 'Cable Canon Canon Xlr/xlr Ross 6 Metros',
#   'Precio': '10.152',
#   'Rating': '4.6',
#   'Reseña': 'Cable prolijo, conectores buenos pero el forro del cable es más plástico que goma, se nota que en algo abarataron. Si vas a tenerlos fijos en estudio dale gas. Si lo tuyo es vivo y movimiento olvidate.'},
#  {'Nombre': 'Hub Usb 4 Puertos 2.0 Multipilicador Switch Luz Adaptador',
#   'Precio': '4.144',
#   'Rating': '4.2',
#   'Reseña': 'Funciona muy bien se puede apagar cada puerto que no usa , la calidad no parece la mejor per cumple su función en relación al precio.'},
#  {'Nombre': 'Cable de alimentación para cargador de notebook Clon Trebol de 150m de largo negro 220V',
#   'Precio': '7.170',
#   'Rating': '4.8',
#   'Reseña': 'Buenísima terminación.\nEstuve buscando en locales de compu y no me animaba a comprar ninguno porque parecían berretas.\nEste tiene excelente aspecto, parece bueno.\nVeremos con el tiempo, pero ya en cuanto a terminación de producto, se ve de mejor calidad que los genéricos.'},
#  {'Nombre': 'Cable Displayport 1.4 8k @60hz / 4k @144hz / 2k @165hz 2.2mt',
#   'Precio': '26.999',
#   'Rating': '4.8',
#   'Reseña': 'Godines mal, me salió un cupón y lo pague 9 lucas.\nMaquina maquiavélica del mal, se lo clave a la 3060ti y ando fero.'},
#  {'Nombre': 'Adaptador Genius 5 En 1 Mod. Uh-545 Hub Usb C A Red Usb Color Gris',
#   'Precio': '35.999',
#   'Rating': '4.7',
#   'Reseña': 'Sirve para crhomecast.'},
#  {'Nombre': 'Cable Display Port 2.1 UGREEN 16K 30Hz - 3 Metros - HDR10+ G-Sync HDCP Freesync - Hasta 240hz 1080P 80Gbps 3D - Trenzado Negro - Premium Gaming - Para PC Gamer Consola Monitor Pantalla - DP118 25862',
#   'Precio': '27.019',
#   'Rating': 'Sin rating',
#   'Reseña': 'Sin reseña'},
#  {'Nombre': 'Cable Hub Pst Para Compartir Fan Cooler Pwm Control Mineria',
#   'Precio': '4.300',
#   'Rating': '4.7',
#   'Reseña': 'Baratito, cumplen su función por el momento. Conecté dos coolers porque mí placa madre tenía para uno solo, ta bueno funciona.'},
#  {'Nombre': 'Cámara instantánea Fujifilm Instax Kit Mini 12 + 20 Films clay/white',
#   'Precio': '268.000',
#   'Rating': '5.0',
#   'Reseña': 'Apropiado, por la relacion precio / calidad.'},
#  {'Nombre': 'Zhiyun Smooth Q3 Gimbal Estabilizador 3 Ejes Celular Smartphone Color Gris',
#   'Precio': '274.999',
#   'Rating': '4.8',
#   'Reseña': 'Favil de instalar tiene todas las funciones de otros mas costosos, es un gimbal perfecto para aprender, para un uso domestico y logras tomas profesionales segun tu habilidad y creatividad.'},
#  {'Nombre': 'Impresora multifunción a color Brother InkBenefit Tank DCP-T220 220V',
#   'Precio': '310.965',
#   'Rating': '4.7',
#   'Reseña': 'Realmente es excelente. Llevo cientos de hojas impresas tanto en blanco y negro como a color y la tinta sigue casi igual a que cuando la compré. La recomiendo muchísimo tanto para estudiantes como para docentes. Excelente compra. Eso si: a veces a la madrugada le pinta hacer mucho ruido para que no se seque la tinta de los cabezales y te pegás un susto terrible y se despierta toda la familia jaja, pero recomiendo al 100%.'},
#  {'Nombre': 'Canon EOS Rebel T7 DSLR color negro',
#   'Precio': '1.227.584',
#   'Rating': '4.8',
#   'Reseña': 'Impecable el producto , además viene con cargador , batería y memoria de 32 gb.'},
#  {'Nombre': 'Impresora Epson Ecotank L1250 Color Con Wifi Color Negro',
#   'Precio': '449.999',
#   'Rating': '4.7',
#   'Reseña': 'Las fotos no salen bien. Me hace renegar bastante. Deja marcas hay que limpiarla constantemente. No volvería a comprarla.'},
#  {'Nombre': 'Camara Fotos Canon Eos Rebel T100 18-55mm Wifi',
#   'Precio': '1.196.799',
#   'Rating': 'Sin rating',
#   'Reseña': 'Sin reseña'},
#  {'Nombre': 'Panel Fotografia Led Luz Estudio Colores Profesional Tripode Color de la estructura Negro Color de la luz Blanco cálido',
#   'Precio': '21.799',
#   'Rating': '4.4',
#   'Reseña': 'Me encantó el panel, soy maquilladora y para subir contenido me estaría sirviendo, seguramente compré uno más ya que creo que ilumina mejor que un aro de luz, para instalarlo hay que agarrarle la mano pero se puede direccionar para que quede justo en un punto fijo.'},
#  {'Nombre': 'Tarjeta de memoria SanDisk SDSQUNR-128G-GN6TA Ultra con adaptador SD 128GB',
#   'Precio': '23.099',
#   'Rating': '4.8',
#   'Reseña': 'La verdad que anduvo muy bien, me emocioné mucho al lograr en esa pequeña tarjeta guardar tantos recuerdos y fotos a pesar que cuando era joven teníamos que ir a revelar los royos que eran tan caros, que bárbaro, ahora ya no, sacamos fotos que se guardan hasta en las nubes. En las nubes? si si es así, miras el cielo y así es, en algún lugar recondito de tanto vapor se ve que hay muchas tarjetitas de estás, ojalá llovieran tarjetitas y no tuviera que comprarlas. Bueno saluditos gente me quedan mil caracteres pero ya me dió sueño.'},
#  {'Nombre': 'Microscopio Digital Portable 1000x 1080p Escritorio Display Color Blanco',
#   'Precio': '142.999',
#   'Rating': '4.7',
#   'Reseña': 'Muy bueno.'},
#  {'Nombre': 'Aro De Luz Cálida Fría Led 36 Cm Profesional Gadnic + Soporte Celular Luz Cálido/Frio',
#   'Precio': '159.999',
#   'Rating': '4.7',
#   'Reseña': 'Es un aro con luz potente regulable, un poco pesado obviamente por sus componentes plásticos de buena calidad.'},
#  {'Nombre': 'Trípode Para Cámara Gopro AFAEM-002 3-way 2.0 3 En 1',
#   'Precio': '117.499',
#   'Rating': '5.0',
#   'Reseña': 'Sin reseña'},
#  {'Nombre': 'Modulo Flash LED Oficial para Gopro Hero 8 9 10 11 12 13 200 Lumens Batería Recargable 6Hs Sumergible 10Mts Temperatura 5700k Altsc-001 color negro',
#   'Precio': '78.841',
#   'Rating': '5.0',
#   'Reseña': 'Excelente original.'},
#  {'Nombre': 'Smart TV Philips 50PUD7408/77 50" 4K LED',
#   'Precio': '899.999',
#   'Rating': '4.7',
#   'Reseña': 'Se la regalé a mi novia por su cumple y no dejamos de ver pelis. Recomiendo. Quedé como un campeón adelante de su papá que le regaló unas pantuflas.'},
#  {'Nombre': 'Smart Tv Quint 43 Pulgadas Qt3-43gtv2024 Full Hd Google Tv',
#   'Precio': '513.999',
#   'Rating': '4.9',
#   'Reseña': 'Excelente producto, me encantó!! imagen buenisima, audio no es malo,zafa!!.'},
#  {'Nombre': 'Smart Tv Quint 32 Pulgadas Qt3-32gtv2024 Google Tv Lh',
#   'Precio': '491.999',
#   'Rating': '4.8',
#   'Reseña': 'Lastima que me vino sin las patas y lo tuve q poner asi hasta comprar el soporte.'},
#  {'Nombre': 'Smart Tv Sansei Led Full Hd 42 Pulgadas Android Tv',
#   'Precio': '629.999',
#   'Rating': '4.7',
#   'Reseña': 'Muy buen producto por precio y calidad. Medio pocho el sonido pero no se le puede pedir más.'},
#  {'Nombre': 'Tv Led Noblex 55 Dk55x7500 Smart Ultra Hd 4k Google Tv/usb',
#   'Precio': '1.380.000',
#   'Rating': '5.0',
#   'Reseña': 'Muy bueno.'},
#  {'Nombre': 'Smart TV de 50" Kanji KJ-5XST005-2 con pantalla LED 4K',
#   'Precio': '569.999',
#   'Rating': '4.7',
#   'Reseña': 'Me pareció excelente producto y de muy buena calidad sorprendido por el sonido mejor q los philips y las prestaciones.'},
#  {'Nombre': 'Televisor Smart Tv Hisense 32 Hd - 32a42k',
#   'Precio': '320.000',
#   'Rating': '4.6',
#   'Reseña': 'Excelente tv , ideal para espacios reducidos.'},
#  {'Nombre': 'Smart Tv Kanji 40" Kj-40st005-2 Led Hd 60Hz Googletv',
#   'Precio': '454.999',
#   'Rating': '4.8',
#   'Reseña': 'Esta muy bien. Para el precio y el tamaño funciona perfecto. Tener google tv incluido es un golazo.'},
#  {'Nombre': 'Smart Tv Led 32 Hd Smart Android Bgh 240v',
#   'Precio': '323.856',
#   'Rating': '4.7',
#   'Reseña': 'No sé que mas puede pedir un usuario de steaming de un smart. Tiene todo lo necesario, le instalas desde android la aplicacion que quieras, el volumen maximo es exageradamente alto, se usa a un 30% maximo.\nGran imagen. No le doy un uso demsiado sofisticado, asi que, para un hogar que apenas mira series y peliculas. Tiene todo.'},
#  {'Nombre': "Televisor Samsung Smart Tv Negro T4300 - Pantalla 32'' Hd",
#   'Precio': '379.999',
#   'Rating': '4.6',
#   'Reseña': 'No le doy las 5, porq me volví loco para encontrar los 4 tornillos para colgarlo al soporte de pared. Estuve a punto de devolver el soporte x ese tema. Dato: son tornillos m4 x 30mm, si es q lo van a comprar. El smart todo bien.'},
#  {'Nombre': 'Smart Tv Samsung 55 Cristal Uhd 4k Cu7000',
#   'Precio': '1.249.999',
#   'Rating': '4.8',
#   'Reseña': 'Está bueno para mirar el chavo del 8.'},
#  {'Nombre': "Smart Tv Sansei TDS2440HIPI 40'' Led Hd Vidaa",
#   'Precio': '593.999',
#   'Rating': '4.7',
#   'Reseña': 'Hace solo dos días lo estoy probando y hasta ahora todo excelente, linda imagen, excelente hasta demasiado volumen, buena conexión, buen sistema. Lo único que me dió bronca que lo bajaron 40 mil pesos inmediatamente después de que hice la compra jajaja pero bueno hasta ahora todo genial volvería a comprarlo. El control es estético y viene con las pilas. Gracias!.'},
#  {'Nombre': 'Smart Tv Philips 32PHD6918/77 32" HD Led',
#   'Precio': '327.331',
#   'Rating': '4.7',
#   'Reseña': 'Hermoso televisor se lo compré a mi vieja y está perfecto! control, apps todo muy 10/10.'},
#  {'Nombre': 'Smart Tv LG 43 Lm6350psb Hdr Full Hd Bluetooth Webos 4.0',
#   'Precio': '469.999',
#   'Rating': '4.8',
#   'Reseña': 'Increíble, la verdad. Superó mis espectativas.\nHace un año compré uno de otra marca y quedé decepcionado pero con este estoy chocho.\nEstá la compré para el mundial y la voy a re aprovechar, nos vamos a ver hasta costa rica vs japón que juegan el domingo 27/11 a las 7 de la mañana.\nViene con algunas aplicaciones que andan muy bien y la función de transmitir pantalla también anduvo de lujo. El sonido también me pareció piola porque no tiene los parlantes atrás.\nEl sistema de puntero tipo la wi es re práctico para navegar.\nLo mejor de todo es que lo compré a 43 lucas y a los 15 días estaba a 100000 lucas, me sentí un experto financiero. Ah sí en qué estaba? la tele.\nExcelente muy muy buena.'},
#  {'Nombre': 'Tcl Qled 55c655 Uhd Google Tv-rv',
#   'Precio': '929.999',
#   'Rating': '4.6',
#   'Reseña': 'Nosotros lo usamos de monitor de una pc gamer. Así que mi opinión está dirigida a ese uso específico. La parte de smart se ve bien pero no la uso. La imagen se ve muy bien y con su funcionalidad hdr mejor todavía, los juegos se ven espectaculares y la películas 4k hdr qled buenísimas, parece que estas ahí dentro, bien resaltados los colores, buena vista de las partes oscuras. Estábamos en duda entre este y un samsung 4k led de los básicos y este se ve mejor, no me arrepiento. A tener en cuenta: el cable hdmi que uses tiene que ser versión 2. 1 a lo sumo 2. 0 con versiones inferiores no anda.'},
#  {'Nombre': 'Smart TV Philips 55PUD7408/77 55" 4K LED',
#   'Precio': '773.594',
#   'Rating': '4.7',
#   'Reseña': 'Tremenda tele.\nEl sonido es excelente y la imagen aun mejor.\nAguante boca.'},
#  {'Nombre': "Smart Tv Noblex Dv32x5050 32'' HD LED Vidaa",
#   'Precio': '320.196',
#   'Rating': '4.8',
#   'Reseña': 'El producto me pareció de muy buena calidad. Alcanzo mi expectativa.'},
#  {'Nombre': "Smart Tv Bgh 32'' Hd Control Por Voz Y Android Tv B3222s5a",
#   'Precio': '319.999',
#   'Rating': '4.6',
#   'Reseña': 'Leí comentarios de que no se podía descargar star, de las etiquetas que trae pegadas en la panitalla. Yo descargué sin problemas star, saque las etiquetas muy fácilmente. Estoy chocha. Cabe destacar que hace un día lo uso. Mi mamá es no vidente y lo maneja de primera, o sea es muy fácil de usar.'},
#  {'Nombre': 'Smart Tv Kanji 40 Led Android Tv Fhd 220v Kj-4xtl005 Negro 220V',
#   'Precio': '354.443',
#   'Rating': '4.5',
#   'Reseña': 'Instalé todas las aplicaciones de cine y series (hbo+ disney, star+ etc) sin dificultad y funcionan perfectamente. El sonido está muy bien pero no puede compararse con el de mí smart sanyo de 32". La calidad de la imagen es buena, tiene ultra hd y se nota mucho, pero al ser 2k no tiene la mejor definición. El control remoto funciona genial y tiene acceso directo a las app más importantes, como la mayoría, así que no hay nada que objetar. No probé las patas, lo colgué directamente en la pared con un soporte bastante baratito que también compré acá y que se la banca un paquetón!!.\nAl tele lo compré muy en oferta, así que no podría ser objetiva en la relación precio-calidad. Puedo decir que lo estoy disfrutando un montón y que el androidetv es un golazo.'},
#  {'Nombre': 'Auriculares Inalámbricos Lenovo Livepod Lp75 Bluetooth Negro',
#   'Precio': '37.399',
#   'Rating': '4.7',
#   'Reseña': 'Los audifonos son buenos los llevo usando 1 mes, el volumen es bajo para anteriores auriculares que he tenido, pero casi no se nota, son comodos, viajo al trabajo 3 horas y tiene autonomia sin problema, son seguros ya que no se caen si te duermes en el tren, en el gym no se me caen tampoco, y tiene buena coneccion ya que el celu lo dejo en el cancel (el gym no es tan grande tampoco), se pausa con 2 toques facilmente y se sube y baja el volumen con 1 toque sin problemas, con 3 toques pasa a la siguiente canción, mi telefono es samsung. Los toques no se activan con el cabello o el gorro como me pasaba con otros auriculares.'},
#  {'Nombre': 'Torre De Sonido Jvc Xs-la5214pb Bluetooth 4800w Con Micrófono',
#   'Precio': '399.999',
#   'Rating': '5.0',
#   'Reseña': 'Sin reseña'},
#  {'Nombre': 'Auriculares Inalámbricos Bluetooth Sony WH-CH520 Negro',
#   'Precio': '78.999',
#   'Rating': '4.8',
#   'Reseña': 'Sin reseña'},
#  {'Nombre': 'Parlante Portátil Philco Djp125 6200w Bluetooth con Manija, Ruedas + Micrófono y Control',
#   'Precio': '299.999',
#   'Rating': '5.0',
#   'Reseña': 'Sin reseña'},
#  {'Nombre': 'Auriculares In-ear Xiaomi Redmi Buds Essential Black Color Negro',
#   'Precio': '30.499',
#   'Rating': '4.3',
#   'Reseña': 'Tampoco te voy a decir que se escucha woooow pero del cable a esto hay un abismo! uno me queda de 10, el otro se me cae un poco pero está genial que vienen con 3 medidas para adaptar! aíslan bastante el sonido exterior, para caminar por la calle voy con uno solo porque si no no la cuento.'},
#  {'Nombre': 'Auriculares Inalámbricos Jbl Wave Buds 2 Bt 40hs Color Negro',
#   'Precio': '109.999',
#   'Rating': '4.8',
#   'Reseña': 'La verdad que son buenisimos lo que más me gustó es la duración de la batería🫶🏽.'},
#  {'Nombre': 'Parlante JBL Charge 5 JBLCHARGE5 portátil con bluetooth waterproof red 220V',
#   'Precio': '347.442',
#   'Rating': '4.8',
#   'Reseña': 'Es todo lo que puede ser un parlante de este tamaño. El sonido no creo que pudiese ser mejor para el tamaño que tiene. No creas que estás en una disco obviamente, pero no creo que pueda mejorarse mucho más dentro de este tamaño. La potencia sonora es increíble, tira y mucho. La señal bluetooth sigue y sigue desde lejos, lo probé como a 10 metros y con muchos obstáculos, no sé cómo siguió funcionando y seguía controlando el volumen. Los materiales, premium, de una, y el diseño buenísimo! sería el iphone de los parlantes bluetooth portátiles. No le pongo 4 estrellas porque con volumen se pierden los bajos, pero supongo que es inevitable, hay un límite físico ineludible. No probé sumergirlo, confío que se la banque. En fin, esta gente de jbl claramente sabe lo que hace.'},
#  {'Nombre': 'Amazon Echo Dot 5th Gen con asistente virtual Alexa Glacier White 110V/240V sin reloj',
#   'Precio': '109.947',
#   'Rating': '4.8',
#   'Reseña': 'Muy copado, si te gusta escuchar musica al mango y que no se sature, elegiste bien. Encima cuando le preguntas que dia es siempre te tira un comentario buena onda, tipaza mal alexa.'},
#  {'Nombre': 'Auriculares Inalámbricos Bluetooth Sony WH-CH520 Crema',
#   'Precio': '78.999',
#   'Rating': '4.8',
#   'Reseña': 'Sin reseña'},
#  {'Nombre': 'Microsistema Philips TAM3205/12',
#   'Precio': '358.359',
#   'Rating': '4.6',
#   'Reseña': 'El equipo la verdad es muy bueno, su volumen en normal. Si queres reventar los vidrios de tu casa escuchando música, no es tu equipo. Porque le vas hacer mierda los parlantes. Una observación es que cuando usas el bluetooh el volumen es relativamente bajo lo tenes que poner en 20 para escuchar un lindo volumen, en comparación la radio con un volumen de 10 se escucha muy bien. Precio calidad.'},
#  {'Nombre': 'Radio Portatil Am Fm A Pilas Y Electrica Winco W-1231 Manija',
#   'Precio': '39.999',
#   'Rating': '4.5',
#   'Reseña': 'Muy buena recepcion ( en am) en sitios alejados. Por lejos, superior a la del auto.'},
#  {'Nombre': 'Auriculares in-ear inalámbricos JBL  Wave Buds blanco',
#   'Precio': '129.999',
#   'Rating': '4.7',
#   'Reseña': 'La peor compra que hice en mi vida. Se los regale a mi hija, si antes no me escuchaba, ahora menos. El producto es buenísimo!!!.'},
#  {'Nombre': 'Amazon Echo Pop con asistente virtual Alexa Control de Voz Charcoal',
#   'Precio': '78.847',
#   'Rating': '4.8',
#   'Reseña': 'Es una masa, compre este y un echo dot 4gen, sinceramente no vale la pena el dot 4, mil veces este echo pop, la calidad de sonido es muy superior y ademas es increíble que sea mas chico con igual potencia y mucha mejor calidad. Si estas entre este y un echo dot 4 o 5, tirate por este.'},
#  {'Nombre': 'Parlante Jbl Go 2 Portátil Con Bluetooth Deep Sea Blue',
#   'Precio': '61.675',
#   'Rating': '4.8',
#   'Reseña': 'Tremendo. Anda fenómeno!.'},
#  {'Nombre': 'Torre De Sonido Samsung Mx-t70 1500w Color Black',
#   'Precio': '1.349.999',
#   'Rating': '4.8',
#   'Reseña': 'Lo compre pensando en la sensación estereo y si olvídate no hay con q darle es samsung. Tengo un departamento lo uso en el living comedor cocina je es un ambiente de 4m x 7m y lo que suena es increíble. Llega al volumen 50 lo uso conectado a un chromecast gen4 q está puesto en la tv y nada la versatilidad de conectividad es hermosa jamas satura estando al máximo el bajo de perfecto tiene un función q lo interesifica aún más desde un botón en su panel. Tiene pregrabado varias escualizaciones todas son exelentes es cuestión de gusto. Estoy juntando gita me voy a comprar el mismo modelo mx-t70 para mí habitación asi lo conecto a mi otra tv necesito conocer como sonarían en todo el depto usando el modo party. Me enamore del equipo. Muy buena tecnología. Compra q no te vas arrepentir.'},
#  {'Nombre': 'Bafle Activo Lexsen X5 Con Bluetooth Tws Fx 150w Rms Color Negro',
#   'Precio': '252.990',
#   'Rating': '4.6',
#   'Reseña': 'La verdad muy buen producto calidad precio. Excelente potencia. Y buena calidad de audio. Más que conforme. Los vecinos están chochos (guiño ,guiño ).'},
#  {'Nombre': 'Parlante Jbl Inalámbrico Bluetooth Go Essential 3.1w Negro 3.7v',
#   'Precio': '72.999',
#   'Rating': '4.8',
#   'Reseña': 'Perfecto x su tamaño.'},
#  {'Nombre': 'Auriculares in-ear inalámbricos JBL TWS Wave Buds Tws JBLWBUDS negro',
#   'Precio': '129.999',
#   'Rating': '4.8',
#   'Reseña': 'Llevando el celu en el bolsillo se corta la música.'},
#  {'Nombre': 'Auriculare Kz Edx Pro - Con Micrófono - Hifi Alta Definición Color Negro',
#   'Precio': '30.000',
#   'Rating': '4.7',
#   'Reseña': 'Yo personalmente vengo de usar los kz zs3 (mis primeros iems) y me costó tomar la decisión, ya que estaba entre este y otros mas. Vi muchos análisis/ reviews de diferentes modelos y marcas para buscar la mejor calidad dentro de tan corto presupuesto, y terminé eligiendolos porque si nomás, ya que no me decidia y me enojó mi propia indecisión. La cosa es que ahora que los probé me doy cuenta de que eligiera estos o unos kz castor o lo que fuere, realmente no notaría la diferencia, asi que solo queria decirlo para aquel que esté indeciso. Cuando los "audiofilos" dicen que los agudos les hacen doler los oidos, o que los graves tapan todo el resto, yo creo que son cosas muy sutiles que ellos exageran y nos hacen pensar cualquier cosa. Así que si estas leyendo esto, no des mas vueltas y compralos. Eso si, espero que te pongas a escuchar un buen disco de phil collins por lo menos, si es para reggaeton anda a comprarte unos auriculares bluetooth al chirola.\nDisfruten la música gordos.'},
#  {'Nombre': 'Control Remoto Para Hitachi Rca Tcl Smart tv L32S6500 L40S6500 L42S6500 40S65A L50P8M L55P8M L65P8M L75P8M XC32SM XC40SM X50ANDTV X55ANDTV X65ANDTV CDH-LE504KSMART20 CDH-LE554KSMART20 CDH-LE32SMART17',
#   'Precio': '7.931',
#   'Rating': '4.6',
#   'Reseña': 'Excelente producto, ojo no tiene comando de voz.'},
#  {'Nombre': 'Control Remoto Smart Tv Para Samsung Todos Los Modelos',
#   'Precio': '3.548',
#   'Rating': '4.5',
#   'Reseña': 'Es idéntico al original pero la calidad constructiva es notoriamente floja. Funciona lo más bien y sin ningún tipo de configuración necesaria. Gran opción para cuando el perro se deglutió el original.'},
#  {'Nombre': 'Control Remoto Para Smart Tv Noblex Hisense Philco En2h27',
#   'Precio': '6.003',
#   'Rating': '4.6',
#   'Reseña': 'Maravilloso. Cuándo las cosas son perfectamente cómo lo necesitas, me cuesta hasta creerlo. Gracias.'},
#  {'Nombre': 'Control Remoto Para Tv Box Genérico Compatible Android Tv',
#   'Precio': '5.700',
#   'Rating': '4.8',
#   'Reseña': 'Excelente. Gracias.'},
#  {'Nombre': 'Control Remoto Para Bgh Telefunken, Kodak Smart Con Netflix Gallio Electrónica',
#   'Precio': '8.699',
#   'Rating': '4.8',
#   'Reseña': 'Excelente calidad y la verdad muy satisfecha solamente puse pilas y lo pude usar sin problemas super recomendable🤩🤩🤩 ya como les dije sin problema la foto lo dice todo. 🤗🤗🤗.'},
#  {'Nombre': 'Control Remoto One For All 6819',
#   'Precio': '5.800',
#   'Rating': '4.3',
#   'Reseña': 'Lo único que se debe tener en cuenta es que el viejo control funcione de alguna forma para poder emparentarlo con el one for all.'},
#  {'Nombre': 'Modulo Oscilador De Potencia Hemmel Para Fuente De Tv Lcd Led 180w Universal De 14 A 60 Pulgadas',
#   'Precio': '3.892',
#   'Rating': '5.0',
#   'Reseña': 'Perfecto. Ya use en una fuente dañada de un led tv 32 pulgadas. Y me sirvió para saber si el problema era en el secundario o en el primario de una fuente de un trc 14".'},
#  {'Nombre': 'Kit Led 43lj5500 43lj5550 43uj6300 43lk5700 43lj551',
#   'Precio': '25.990',
#   'Rating': '4.8',
#   'Reseña': 'Mi lg 43" 5500 estaba azul. Coloque estos led con un tutorial de youtube y problema solucionado. Hasta ahora sin fallas.'},
#  {'Nombre': 'Kit de 8 barras 47lb5600 47lb5800 47lb 47lb6500',
#   'Precio': '34.590',
#   'Rating': '4.6',
#   'Reseña': 'Muy buenos los repuestos quedó de diez.'},
#  {'Nombre': 'Smart Tv Samsung 2021 Un50au7000gczb Uhd Tizen Led 50 Negro',
#   'Precio': '775.749',
#   'Rating': '4.7',
#   'Reseña': 'Muy conforme, lo vale al 100%. Pero bueno me pide que escriba algo mas asi que les dejo la receta de un vitel toné.\nMarinar el peceto en vino blanco y dejarlo reposar durante toda la noche.\nAtar el peceto con un hilo para darle una forma y que sea más práctico cocinarlo.\nPoner el peceto en una olla, ponerle un poco de vino blanco, agua, el caldo y una hoja de laurel.\nCocinar el peceto durante una hora.\nTomar una licuadora y mezclar una cucharada de caldo, las yemas de dos huevos duros, lata de atún, las anchoas, una cucharada de vinagre, jugo de limón, sal, pimienta, una cucharada de mostaza, dos cucharadas de mayonesa y una cucharada de alcaparras.\nLicuar la pasta para hacer la salsa del peceto.\nLuego de tener la carne cocinada, tomar un cuchillo y cortarla de manera fina.\nTomar una fuente, poner la carne en una hilera y cubrirla de salsa.\n¡listo! ya podés disfrutar de un gran vitel toné para las fiestas de navidad y año nuevo.'},
#  {'Nombre': 'Tv Led Noblex Db24x4000 24 Hd',
#   'Precio': '215.296',
#   'Rating': '4.3',
#   'Reseña': 'Lo que estaba necesitando,.\nUn televisor pequeño para mi dormitorio. Buena compra.'},
#  {'Nombre': 'Smart Tv Noblex DV32X7000 32" HD Led',
#   'Precio': '489.106',
#   'Rating': '4.8',
#   'Reseña': 'Buen. Producto. Ya conozco la firma. Yo tengo un let misma marca.'}]

# %%
len(productos)
# Out:
# 164
